# %% [markdown]
# # Factor Research Pipeline
#
# Template standar untuk riset Alpha Factor baru. Setiap faktor baru **wajib dievaluasi** menggunakan **IC (Information Coefficient)** terhadap forward return sebelum dimasukkan ke dalam production feature store.
#
# ## Kriteria Lolos (Production Threshold)
# - **Mean IC > 0.05** (Absolute) secara konsisten
# - **IC / IC Std (Information Ratio) > 0.5**
# - P-Value < 0.05 pada mayoritas observasi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from utils.factor_eval import FactorEvaluator

# %% [markdown]
# ## 1. Load Data & Define Factor

# %%
# df = pd.read_csv('../../dataset/XAUUSD_DEFAULT.csv')
# df['time'] = pd.to_datetime(df['time'])
# df.set_index('time', inplace=True)

# Definisikan Alpha Factor Anda di sini
# Contoh:
# df['my_alpha_factor'] = df['close'].pct_change(5) - df['close'].pct_change(10)

# %% [markdown]
# ## 2. Hitung Forward Returns & Information Coefficient (IC)

# %%
# returns_df = FactorEvaluator.compute_forward_returns(df, periods=[1, 5, 15, 60])
# ic_df = FactorEvaluator.calculate_ic(df, returns_df, ['my_alpha_factor'])
# display(ic_df)

# %% [markdown]
# ## 3. Rolling IC (Stability Check)

# %%
# rolling_ic = FactorEvaluator.calculate_rolling_ic(df, returns_df, 'my_alpha_factor', 'fwd_ret_15', window=500)
# rolling_ic.plot(title="Rolling IC (Window=500)")
# plt.axhline(0.0, color='red', linestyle='--')
# plt.show()
